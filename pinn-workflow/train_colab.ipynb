# %%
# !git clone -b reset-changes https://jadelee@github.com/hanb0i/Basic-PiNN-Model-For-Three-Layered-Collision.git
# Out:
# Cloning into 'Basic-PiNN-Model-For-Three-Layered-Collision'...
# remote: Enumerating objects: 731, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 731 (delta 84), reused 116 (delta 48), pack-reused 562 (from 1)
# Receiving objects: 100% (731/731), 22.33 MiB | 43.38 MiB/s, done.
# Resolving deltas: 100% (372/372), done.

# %%
import os, sys
from pathlib import Path

repo_root = Path('/content/Basic-PiNN-Model-For-Three-Layered-Collision')
pinn_dir = repo_root / 'pinn-workflow'
sys.path.insert(0, str(pinn_dir))
os.chdir(pinn_dir)

# %%
# !pwd
# !ls
# Out:
# /content/Basic-PiNN-Model-For-Three-Layered-Collision/pinn-workflow
# data.py		  model.py    pinn_config.py  __pycache__  train_colab.ipynb
# fea_solution.npy  physics.py  plot.py	      README.md    train.py

# %%
# %cd /content/Basic-PiNN-Model-For-Three-Layered-Collision
# !ls
# Out:
# /content/Basic-PiNN-Model-For-Three-Layered-Collision
# benchmark_fea.py      diagnostics.py	pinn_model.pth
# compare_results.py    fea_solution.npy	pinn-workflow
# comparison_top.png    fea-workflow	__pycache__
# cross_section.png     loss_curve.png	pyproject.toml
# diagnostic_report.md  loss_history.npy	traction_top_patch.png

# %%
# %cd /content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts
# !python run_workflow.py
# Out:
# /content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts
# === Phase 1: Training PINN via pinn-workflow ===
# Using device: cuda
# Starting Adam Training...
# Epoch 0: Total Loss: 123590664.000000 | PDE: 12340744.000000 | BC: 0.000000 | Load: 182.908020 | Interface: 0.173434 | Time: 1.4639s
# Epoch 100: Total Loss: 187387.906250 | PDE: 18662.259766 | BC: 0.000000 | Load: 0.764119 | Interface: 0.003874 | Time: 53.5031s
# Epoch 200: Total Loss: 81206.617188 | PDE: 8088.493164 | BC: 0.000000 | Load: 0.320845 | Interface: 0.003709 | Time: 53.1768s
# Epoch 300: Total Loss: 47696.265625 | PDE: 4751.153320 | BC: 0.000000 | Load: 0.183992 | Interface: 0.003875 | Time: 52.9321s
# Epoch 400: Total Loss: 32114.257812 | PDE: 3198.930908 | BC: 0.000000 | Load: 0.124251 | Interface: 0.004152 | Time: 53.3365s
# Adam Training Complete. Total Time: 267.02s
# Starting L-BFGS Training...
# Running 50 L-BFGS outer steps.
# L-BFGS Step 0: Loss: 23387.789062 | Time: 55.1188s
# L-BFGS Step 1: Loss: 484.879761 | Time: 56.4554s
# L-BFGS Step 2: Loss: 44.273869 | Time: 56.7551s
# L-BFGS Step 3: Loss: 12.227978 | Time: 55.9871s
# L-BFGS Step 4: Loss: 5.330780 | Time: 57.1490s
# L-BFGS Step 5: Loss: 3.216586 | Time: 55.5022s
# L-BFGS Step 6: Loss: 2.006223 | Time: 55.7208s
# L-BFGS Step 7: Loss: 1.360164 | Time: 57.1274s
# L-BFGS Step 8: Loss: 0.959707 | Time: 58.2045s
# L-BFGS Step 9: Loss: 0.707280 | Time: 57.4008s
# L-BFGS Step 10: Loss: 0.531660 | Time: 57.2011s
# L-BFGS Step 11: Loss: 0.421441 | Time: 56.8465s
# L-BFGS Step 12: Loss: 0.339314 | Time: 58.9330s
# L-BFGS Step 13: Loss: 0.280359 | Time: 56.8210s
# L-BFGS Step 14: Loss: 0.233623 | Time: 57.4016s
# L-BFGS Step 15: Loss: 0.200795 | Time: 58.5986s
# L-BFGS Step 16: Loss: 0.173919 | Time: 57.1240s
# L-BFGS Step 17: Loss: 0.149318 | Time: 57.2148s
# L-BFGS Step 18: Loss: 0.128792 | Time: 54.9724s
# L-BFGS Step 19: Loss: 0.111590 | Time: 56.2942s
# L-BFGS Step 20: Loss: 0.098474 | Time: 58.3350s
# L-BFGS Step 21: Loss: 0.088691 | Time: 56.4801s
# L-BFGS Step 22: Loss: 0.079203 | Time: 56.2797s
# L-BFGS Step 23: Loss: 0.070712 | Time: 59.0541s
# L-BFGS Step 24: Loss: 0.063388 | Time: 56.6549s
# L-BFGS Step 25: Loss: 0.056935 | Time: 58.0982s
# L-BFGS Step 26: Loss: 0.052060 | Time: 57.4071s
# L-BFGS Step 27: Loss: 0.047692 | Time: 59.2175s
# L-BFGS Step 28: Loss: 0.043805 | Time: 58.4897s
# L-BFGS Step 29: Loss: 0.040474 | Time: 58.3590s
# L-BFGS Step 30: Loss: 0.037360 | Time: 57.1256s
# L-BFGS Step 31: Loss: 0.034363 | Time: 57.6944s
# L-BFGS Step 32: Loss: 0.032007 | Time: 57.4565s
# L-BFGS Step 33: Loss: 0.029701 | Time: 55.7188s
# L-BFGS Step 34: Loss: 0.027714 | Time: 56.8612s
# L-BFGS Step 35: Loss: 0.026023 | Time: 56.0456s
# L-BFGS Step 36: Loss: 0.024618 | Time: 57.6457s
# L-BFGS Step 37: Loss: 0.023270 | Time: 57.0496s
# L-BFGS Step 38: Loss: 0.021970 | Time: 56.5167s
# L-BFGS Step 39: Loss: 0.020795 | Time: 57.3035s
# L-BFGS Step 40: Loss: 0.019692 | Time: 56.6720s
# L-BFGS Step 41: Loss: 0.018722 | Time: 56.7851s
# L-BFGS Step 42: Loss: 0.017842 | Time: 58.2874s
# L-BFGS Step 43: Loss: 0.016953 | Time: 56.0870s
# L-BFGS Step 44: Loss: 0.016102 | Time: 56.1738s
# L-BFGS Step 45: Loss: 0.015398 | Time: 57.4630s
# L-BFGS Step 46: Loss: 0.014804 | Time: 55.6848s
# L-BFGS Step 47: Loss: 0.014155 | Time: 58.2828s
# L-BFGS Step 48: Loss: 0.013530 | Time: 58.3057s
# L-BFGS Step 49: Loss: 0.012963 | Time: 57.3642s
# Model saved.
# Saved loss_history_plot.png to /content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts
# Saved lbfgs_loss_plot.png to /content/Basic-PiNN-Model-For-Three-Layered-Collision/fea-workflow/scripts
#
# === Phase 2: Running FEA Benchmark ===
# Initializing FEA Solver...
# Assembling...
# Solving...
#
# === Phase 3: Comparison ===
# Comparison: Max FEA -0.6730, Max PINN -0.0061
# Workflow Complete. Comparison plots generated.

# %%
from IPython.display import Image, display

display(Image("loss_curve.png"))
display(Image("displacement_top.png"))
display(Image("cross_section.png"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1288         if self.embed:
#    1289             mimetype = self._mimetype
# -> 1290             data, metadata = self._data_and_metadata(always_both=True)
#    1291             if metadata:
#    1292                 metadata = {mimetype: metadata}
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'loss_curve.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_png_(self)
#    1318     def _repr_png_(self):
#    1319         if self.embed and self.format == self._FMT_PNG:
# -> 1320             return self._data_and_metadata()
#    1321
#    1322     def _repr_jpeg_(self):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'loss_curve.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1288         if self.embed:
#    1289             mimetype = self._mimetype
# -> 1290             data, metadata = self._data_and_metadata(always_both=True)
#    1291             if metadata:
#    1292                 metadata = {mimetype: metadata}
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'displacement_top.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_png_(self)
#    1318     def _repr_png_(self):
#    1319         if self.embed and self.format == self._FMT_PNG:
# -> 1320             return self._data_and_metadata()
#    1321
#    1322     def _repr_jpeg_(self):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'displacement_top.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1288         if self.embed:
#    1289             mimetype = self._mimetype
# -> 1290             data, metadata = self._data_and_metadata(always_both=True)
#    1291             if metadata:
#    1292                 metadata = {mimetype: metadata}
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'cross_section.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _repr_png_(self)
#    1318     def _repr_png_(self):
#    1319         if self.embed and self.format == self._FMT_PNG:
# -> 1320             return self._data_and_metadata()
#    1321
#    1322     def _repr_jpeg_(self):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
# -> 1302             raise FileNotFoundError(
#    1303                 "No such file or directory: '%s'" % (self.data))
#    1304         md = {}
#
# FileNotFoundError: No such file or directory: 'cross_section.png'

# %%
# %cd
# Out:
# /root
