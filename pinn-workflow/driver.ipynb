# %%
import os
os.chdir('/users/zzhan536/myData/Tutoring/mechanics_PINN/Basic-PiNN-Model-For-Three-Layered-Collision/pinn-workflow')
print(os.getcwd())
# Out:
# /oscar/data/gk/zzhan536/Tutoring/mechanics_PINN/Basic-PiNN-Model-For-Three-Layered-Collision/pinn-workflow

# %% [markdown]
# # Run FEM with Doubled Resolution
#
# Re-run the FEM solver with 60×60×20 mesh (doubled from 30×30×10) to check convergence.

# %%
# Run FEM with soft edge load
import sys
import numpy as np

sys.path.append('../fea-workflow')
from solver.fem_solver import solve_fem

# Configuration
cfg = {
    'geometry': {
        'Lx': 1.0,
        'Ly': 1.0,
        'H': 0.1
    },
    'material': {
        'E': 1.0,
        'nu': 0.3
    },
    'load_patch': {
        'x_start': 0.33,
        'x_end': 0.67,
        'y_start': 0.33,
        'y_end': 0.67,
        'pressure': 1.0
    }
}

print("Running FEM with soft edge load (30×30×10 mesh)...")
x_nodes, y_nodes, z_nodes, u_grid = solve_fem(cfg)

# Save
X_fea_new, Y_fea_new, Z_fea_new = np.meshgrid(x_nodes, y_nodes, z_nodes, indexing='ij')
result = {
    'x': X_fea_new,
    'y': Y_fea_new,
    'z': Z_fea_new,
    'u': u_grid
}

np.save("fea_solution.npy", result)
print(f"\nFEM solution saved to fea_solution.npy")
print(f"Grid shape: {X_fea_new.shape}")
print(f"Max displacement u_z: {u_grid[:,:,:,2].min():.6f}")
print(f"Peak at center top: {u_grid[len(x_nodes)//2, len(y_nodes)//2, -1, 2]:.6f}")
print(f"Peak at center bottom: {u_grid[len(x_nodes)//2, len(y_nodes)//2, 0, 2]:.6f}")
# Out:
# Running FEM with soft edge load (30×30×10 mesh)...
# Initializing FEA Solver...
# Assembling...
# Solving...
#
# FEM solution saved to fea_solution.npy
# Grid shape: (31, 31, 11)
# Max displacement u_z: -2.980306
# Peak at center top: -2.953146
# Peak at center bottom: -2.907046

# %%
from train import train 
train()
# Out:
# Using device: cuda
# MultiLayerPINN(
#   (layer): LayerNet(
#     (net): Sequential(
#       (0): Linear(in_features=3, out_features=32, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=32, out_features=32, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )
# Loading FEM solution for comparison...
# FEM data loaded: (31, 31, 11)
# Starting SOAP Training...
# Epoch 0: Total Loss: 87.045036 | PDE: 83.388786 | BC_sides: 0.000000 | Free_top: 0.707116 | Free_bot: 0.685138 | Load: 2.263998 | LR: 1.00e-03 | FEM MAE: 0.354225 | Time: 0.0916s
# Epoch 100: Total Loss: 0.271926 | PDE: 0.198384 | BC_sides: 0.000000 | Free_top: 0.008313 | Free_bot: 0.005643 | Load: 0.059586 | LR: 1.00e-03 | FEM MAE: 0.261498 | Time: 8.4195s
# Epoch 200: Total Loss: 0.129409 | PDE: 0.065654 | BC_sides: 0.000000 | Free_top: 0.011987 | Free_bot: 0.007723 | Load: 0.044046 | LR: 1.00e-03 | FEM MAE: 0.258877 | Time: 8.4250s
# Epoch 300: Total Loss: 0.098540 | PDE: 0.036380 | BC_sides: 0.000000 | Free_top: 0.012310 | Free_bot: 0.007923 | Load: 0.041927 | LR: 1.00e-03 | FEM MAE: 0.258542 | Time: 8.4176s
# Epoch 400: Total Loss: 0.083320 | PDE: 0.022688 | BC_sides: 0.000000 | Free_top: 0.011676 | Free_bot: 0.007681 | Load: 0.041275 | LR: 3.00e-04 | FEM MAE: 0.259365 | Time: 8.4186s
#   Resampled with residual-based adaptive sampling at epoch 500
# Epoch 500: Total Loss: 0.086114 | PDE: 0.023884 | BC_sides: 0.000000 | Free_top: 0.012556 | Free_bot: 0.008131 | Load: 0.041543 | LR: 3.00e-04 | FEM MAE: 0.259772 | Time: 8.4788s
# Epoch 600: Total Loss: 0.082079 | PDE: 0.020070 | BC_sides: 0.000000 | Free_top: 0.011193 | Free_bot: 0.007179 | Load: 0.043637 | LR: 3.00e-04 | FEM MAE: 0.260172 | Time: 8.4719s
# Epoch 700: Total Loss: 0.078855 | PDE: 0.017369 | BC_sides: 0.000000 | Free_top: 0.010709 | Free_bot: 0.006968 | Load: 0.043809 | LR: 3.00e-04 | FEM MAE: 0.260680 | Time: 8.4687s
# Epoch 800: Total Loss: 0.076150 | PDE: 0.015227 | BC_sides: 0.000000 | Free_top: 0.010272 | Free_bot: 0.006811 | Load: 0.043840 | LR: 9.00e-05 | FEM MAE: 0.261249 | Time: 8.4767s
# Epoch 900: Total Loss: 0.075411 | PDE: 0.014662 | BC_sides: 0.000000 | Free_top: 0.010140 | Free_bot: 0.006766 | Load: 0.043842 | LR: 9.00e-05 | FEM MAE: 0.261436 | Time: 8.4828s
#   Resampled with residual-based adaptive sampling at epoch 1000
# Epoch 1000: Total Loss: 0.075938 | PDE: 0.015514 | BC_sides: 0.000000 | Free_top: 0.010375 | Free_bot: 0.006825 | Load: 0.043223 | LR: 9.00e-05 | FEM MAE: 0.261638 | Time: 8.5684s
# Epoch 1100: Total Loss: 0.075072 | PDE: 0.014661 | BC_sides: 0.000000 | Free_top: 0.009809 | Free_bot: 0.006434 | Load: 0.044169 | LR: 9.00e-05 | FEM MAE: 0.261849 | Time: 9.4969s
# Epoch 1200: Total Loss: 0.074292 | PDE: 0.014049 | BC_sides: 0.000000 | Free_top: 0.009576 | Free_bot: 0.006326 | Load: 0.044341 | LR: 2.70e-05 | FEM MAE: 0.262084 | Time: 8.7394s
# Epoch 1300: Total Loss: 0.074057 | PDE: 0.013872 | BC_sides: 0.000000 | Free_top: 0.009516 | Free_bot: 0.006302 | Load: 0.044367 | LR: 2.70e-05 | FEM MAE: 0.262158 | Time: 8.4807s
# Epoch 1400: Total Loss: 0.073813 | PDE: 0.013690 | BC_sides: 0.000000 | Free_top: 0.009454 | Free_bot: 0.006279 | Load: 0.044391 | LR: 2.70e-05 | FEM MAE: 0.262237 | Time: 8.4704s
#   Resampled with residual-based adaptive sampling at epoch 1500
# Epoch 1500: Total Loss: 0.074889 | PDE: 0.014390 | BC_sides: 0.000000 | Free_top: 0.009485 | Free_bot: 0.006272 | Load: 0.044743 | LR: 2.70e-05 | FEM MAE: 0.262320 | Time: 8.5434s
# Epoch 1600: Total Loss: 0.074597 | PDE: 0.014087 | BC_sides: 0.000000 | Free_top: 0.009249 | Free_bot: 0.006088 | Load: 0.045173 | LR: 8.10e-06 | FEM MAE: 0.262413 | Time: 8.4708s
# Epoch 1700: Total Loss: 0.074512 | PDE: 0.014014 | BC_sides: 0.000000 | Free_top: 0.009211 | Free_bot: 0.006067 | Load: 0.045220 | LR: 8.10e-06 | FEM MAE: 0.262439 | Time: 8.4813s
# Epoch 1800: Total Loss: 0.074423 | PDE: 0.013941 | BC_sides: 0.000000 | Free_top: 0.009176 | Free_bot: 0.006048 | Load: 0.045259 | LR: 8.10e-06 | FEM MAE: 0.262466 | Time: 8.4746s
# Epoch 1900: Total Loss: 0.074331 | PDE: 0.013867 | BC_sides: 0.000000 | Free_top: 0.009142 | Free_bot: 0.006031 | Load: 0.045291 | LR: 8.10e-06 | FEM MAE: 0.262495 | Time: 8.4876s
# SOAP Training Complete. Total Time: 170.75s
# Starting L-BFGS Training...
# Running 100 L-BFGS outer steps.
# Resampling with residual-based adaptive sampling each outer step.
# L-BFGS Step 0: Total Loss: 7.397741e-02 | PDE: 2.877469e-03 | BC_sides: 0.000000e+00 | Free_top: 3.679686e-03 | Free_bot: 7.901195e-03 | Load: 2.403050e-02 | FEM MAE: 2.698141e-01 | Time: 94.0947s
# L-BFGS Step 1: Total Loss: 4.500994e-02 | PDE: 2.406926e-03 | BC_sides: 0.000000e+00 | Free_top: 3.812574e-03 | Free_bot: 9.453276e-03 | Load: 2.166804e-02 | FEM MAE: 2.703254e-01 | Time: 95.2739s
# L-BFGS Step 2: Total Loss: 4.050213e-02 | PDE: 2.128790e-03 | BC_sides: 0.000000e+00 | Free_top: 3.428803e-03 | Free_bot: 9.383439e-03 | Load: 2.113064e-02 | FEM MAE: 2.714372e-01 | Time: 96.4149s
# L-BFGS Step 3: Total Loss: 3.810681e-02 | PDE: 2.189908e-03 | BC_sides: 0.000000e+00 | Free_top: 2.938026e-03 | Free_bot: 9.944436e-03 | Load: 1.921149e-02 | FEM MAE: 2.720512e-01 | Time: 98.2808s
# L-BFGS Step 4: Total Loss: 3.698013e-02 | PDE: 2.213675e-03 | BC_sides: 0.000000e+00 | Free_top: 2.435982e-03 | Free_bot: 1.011222e-02 | Load: 1.775411e-02 | FEM MAE: 2.710709e-01 | Time: 95.0683s
# L-BFGS Step 5: Total Loss: 3.323742e-02 | PDE: 2.548634e-03 | BC_sides: 0.000000e+00 | Free_top: 1.690219e-03 | Free_bot: 1.031961e-02 | Load: 1.520867e-02 | FEM MAE: 2.670783e-01 | Time: 96.2950s
# L-BFGS Step 6: Total Loss: 2.993422e-02 | PDE: 2.472975e-03 | BC_sides: 0.000000e+00 | Free_top: 1.284679e-03 | Free_bot: 1.045611e-02 | Load: 1.348790e-02 | FEM MAE: 2.651341e-01 | Time: 101.5043s
# L-BFGS Step 7: Total Loss: 2.737101e-02 | PDE: 2.544648e-03 | BC_sides: 0.000000e+00 | Free_top: 9.540661e-04 | Free_bot: 1.059321e-02 | Load: 1.169510e-02 | FEM MAE: 2.640299e-01 | Time: 102.0231s
# L-BFGS Step 8: Total Loss: 2.709395e-02 | PDE: 2.390238e-03 | BC_sides: 0.000000e+00 | Free_top: 8.270488e-04 | Free_bot: 1.186088e-02 | Load: 1.040337e-02 | FEM MAE: 2.623971e-01 | Time: 97.0852s
# L-BFGS Step 9: Total Loss: 2.383620e-02 | PDE: 1.892190e-03 | BC_sides: 0.000000e+00 | Free_top: 7.018325e-04 | Free_bot: 1.072863e-02 | Load: 9.367170e-03 | FEM MAE: 2.616973e-01 | Time: 98.6101s
# L-BFGS Step 10: Total Loss: 2.338724e-02 | PDE: 1.810620e-03 | BC_sides: 0.000000e+00 | Free_top: 6.228595e-04 | Free_bot: 1.130193e-02 | Load: 8.897977e-03 | FEM MAE: 2.601753e-01 | Time: 103.3883s
# L-BFGS Step 11: Total Loss: 2.315238e-02 | PDE: 1.701165e-03 | BC_sides: 0.000000e+00 | Free_top: 5.630884e-04 | Free_bot: 1.148431e-02 | Load: 8.697371e-03 | FEM MAE: 2.601495e-01 | Time: 98.0296s
# L-BFGS Step 12: Total Loss: 2.314928e-02 | PDE: 1.679784e-03 | BC_sides: 0.000000e+00 | Free_top: 5.740111e-04 | Free_bot: 1.214501e-02 | Load: 8.111844e-03 | FEM MAE: 2.581743e-01 | Time: 103.0975s
# L-BFGS Step 13: Total Loss: 2.270000e-02 | PDE: 1.533368e-03 | BC_sides: 0.000000e+00 | Free_top: 5.405442e-04 | Free_bot: 1.192323e-02 | Load: 8.152307e-03 | FEM MAE: 2.576472e-01 | Time: 98.1380s
# L-BFGS Step 14: Total Loss: 2.154815e-02 | PDE: 1.428893e-03 | BC_sides: 0.000000e+00 | Free_top: 4.913803e-04 | Free_bot: 1.162557e-02 | Load: 7.608458e-03 | FEM MAE: 2.576759e-01 | Time: 99.5862s
# L-BFGS Step 15: Total Loss: 2.174907e-02 | PDE: 1.397608e-03 | BC_sides: 0.000000e+00 | Free_top: 4.821580e-04 | Free_bot: 1.175984e-02 | Load: 7.746467e-03 | FEM MAE: 2.580428e-01 | Time: 96.8544s
# L-BFGS Step 16: Total Loss: 2.163707e-02 | PDE: 1.394840e-03 | BC_sides: 0.000000e+00 | Free_top: 5.326478e-04 | Free_bot: 1.175857e-02 | Load: 7.622306e-03 | FEM MAE: 2.574439e-01 | Time: 98.8497s
# L-BFGS Step 17: Total Loss: 2.123532e-02 | PDE: 1.493640e-03 | BC_sides: 0.000000e+00 | Free_top: 4.822752e-04 | Free_bot: 1.137157e-02 | Load: 7.586870e-03 | FEM MAE: 2.572562e-01 | Time: 97.4118s
# L-BFGS Step 18: Total Loss: 2.076488e-02 | PDE: 1.490810e-03 | BC_sides: 0.000000e+00 | Free_top: 5.135221e-04 | Free_bot: 1.116667e-02 | Load: 7.289258e-03 | FEM MAE: 2.563397e-01 | Time: 96.3694s
# L-BFGS Step 19: Total Loss: 2.124419e-02 | PDE: 1.608925e-03 | BC_sides: 0.000000e+00 | Free_top: 4.955286e-04 | Free_bot: 1.127122e-02 | Load: 7.428217e-03 | FEM MAE: 2.553120e-01 | Time: 99.4977s
# L-BFGS Step 20: Total Loss: 2.071290e-02 | PDE: 1.624710e-03 | BC_sides: 0.000000e+00 | Free_top: 4.750659e-04 | Free_bot: 1.086443e-02 | Load: 7.333834e-03 | FEM MAE: 2.543530e-01 | Time: 104.2613s
# L-BFGS Step 21: Total Loss: 2.014709e-02 | PDE: 1.682538e-03 | BC_sides: 0.000000e+00 | Free_top: 4.823170e-04 | Free_bot: 1.056894e-02 | Load: 7.032695e-03 | FEM MAE: 2.534932e-01 | Time: 103.5028s
# L-BFGS Step 22: Total Loss: 2.001018e-02 | PDE: 1.747048e-03 | BC_sides: 0.000000e+00 | Free_top: 4.921056e-04 | Free_bot: 1.026634e-02 | Load: 7.096059e-03 | FEM MAE: 2.527138e-01 | Time: 102.3178s
# L-BFGS Step 23: Total Loss: 2.002176e-02 | PDE: 1.920472e-03 | BC_sides: 0.000000e+00 | Free_top: 4.972672e-04 | Free_bot: 1.026838e-02 | Load: 6.985309e-03 | FEM MAE: 2.508265e-01 | Time: 103.2075s
# L-BFGS Step 24: Total Loss: 1.991041e-02 | PDE: 1.999267e-03 | BC_sides: 0.000000e+00 | Free_top: 5.313960e-04 | Free_bot: 1.040798e-02 | Load: 6.581938e-03 | FEM MAE: 2.498877e-01 | Time: 96.1264s
# L-BFGS Step 25: Total Loss: 1.929238e-02 | PDE: 1.878444e-03 | BC_sides: 0.000000e+00 | Free_top: 5.349948e-04 | Free_bot: 1.017544e-02 | Load: 6.291052e-03 | FEM MAE: 2.494011e-01 | Time: 96.0937s
# L-BFGS Step 26: Total Loss: 1.905263e-02 | PDE: 2.063368e-03 | BC_sides: 0.000000e+00 | Free_top: 5.549501e-04 | Free_bot: 1.005610e-02 | Load: 6.022905e-03 | FEM MAE: 2.480298e-01 | Time: 103.8179s
# L-BFGS Step 27: Total Loss: 1.874075e-02 | PDE: 2.046093e-03 | BC_sides: 0.000000e+00 | Free_top: 5.036710e-04 | Free_bot: 9.655465e-03 | Load: 6.129154e-03 | FEM MAE: 2.474764e-01 | Time: 103.8493s
# L-BFGS Step 28: Total Loss: 1.848057e-02 | PDE: 2.139268e-03 | BC_sides: 0.000000e+00 | Free_top: 4.990548e-04 | Free_bot: 9.434527e-03 | Load: 6.035191e-03 | FEM MAE: 2.470165e-01 | Time: 104.5733s
# L-BFGS Step 29: Total Loss: 1.803990e-02 | PDE: 2.203803e-03 | BC_sides: 0.000000e+00 | Free_top: 5.282501e-04 | Free_bot: 9.203817e-03 | Load: 5.701982e-03 | FEM MAE: 2.453121e-01 | Time: 103.4249s
# L-BFGS Step 30: Total Loss: 1.787062e-02 | PDE: 2.314537e-03 | BC_sides: 0.000000e+00 | Free_top: 5.142635e-04 | Free_bot: 9.089748e-03 | Load: 5.610988e-03 | FEM MAE: 2.441267e-01 | Time: 102.4663s
# L-BFGS Step 31: Total Loss: 1.787038e-02 | PDE: 2.504935e-03 | BC_sides: 0.000000e+00 | Free_top: 5.679507e-04 | Free_bot: 8.801846e-03 | Load: 5.626920e-03 | FEM MAE: 2.426132e-01 | Time: 98.0432s
# L-BFGS Step 32: Total Loss: 1.782344e-02 | PDE: 2.608872e-03 | BC_sides: 0.000000e+00 | Free_top: 5.521794e-04 | Free_bot: 8.717401e-03 | Load: 5.555111e-03 | FEM MAE: 2.417786e-01 | Time: 103.9908s
# L-BFGS Step 33: Total Loss: 1.754053e-02 | PDE: 2.600564e-03 | BC_sides: 0.000000e+00 | Free_top: 5.969209e-04 | Free_bot: 8.445933e-03 | Load: 5.539809e-03 | FEM MAE: 2.404760e-01 | Time: 102.7659s
# L-BFGS Step 34: Total Loss: 1.725672e-02 | PDE: 2.701109e-03 | BC_sides: 0.000000e+00 | Free_top: 5.923144e-04 | Free_bot: 8.191634e-03 | Load: 5.393166e-03 | FEM MAE: 2.393732e-01 | Time: 101.1400s
# L-BFGS Step 35: Total Loss: 1.710848e-02 | PDE: 2.707408e-03 | BC_sides: 0.000000e+00 | Free_top: 6.384711e-04 | Free_bot: 8.090990e-03 | Load: 5.227203e-03 | FEM MAE: 2.390579e-01 | Time: 100.3506s
# L-BFGS Step 36: Total Loss: 1.680564e-02 | PDE: 2.749372e-03 | BC_sides: 0.000000e+00 | Free_top: 6.867685e-04 | Free_bot: 7.808486e-03 | Load: 5.144866e-03 | FEM MAE: 2.375320e-01 | Time: 101.7475s
# L-BFGS Step 37: Total Loss: 1.639096e-02 | PDE: 2.810228e-03 | BC_sides: 0.000000e+00 | Free_top: 6.866107e-04 | Free_bot: 7.681206e-03 | Load: 4.839674e-03 | FEM MAE: 2.369137e-01 | Time: 101.3362s
# L-BFGS Step 38: Total Loss: 1.627253e-02 | PDE: 2.755187e-03 | BC_sides: 0.000000e+00 | Free_top: 6.724386e-04 | Free_bot: 7.403473e-03 | Load: 5.054369e-03 | FEM MAE: 2.362258e-01 | Time: 100.0329s
# L-BFGS Step 39: Total Loss: 1.594109e-02 | PDE: 2.775120e-03 | BC_sides: 0.000000e+00 | Free_top: 6.813642e-04 | Free_bot: 7.164701e-03 | Load: 4.925219e-03 | FEM MAE: 2.359867e-01 | Time: 99.7230s
# L-BFGS Step 40: Total Loss: 1.568520e-02 | PDE: 2.949306e-03 | BC_sides: 0.000000e+00 | Free_top: 6.986581e-04 | Free_bot: 6.917362e-03 | Load: 4.661950e-03 | FEM MAE: 2.342641e-01 | Time: 99.9875s
# L-BFGS Step 41: Total Loss: 1.526016e-02 | PDE: 2.809308e-03 | BC_sides: 0.000000e+00 | Free_top: 7.040105e-04 | Free_bot: 6.611111e-03 | Load: 4.690554e-03 | FEM MAE: 2.333339e-01 | Time: 98.1093s
# L-BFGS Step 42: Total Loss: 1.508654e-02 | PDE: 3.059558e-03 | BC_sides: 0.000000e+00 | Free_top: 7.266341e-04 | Free_bot: 6.387486e-03 | Load: 4.423904e-03 | FEM MAE: 2.314843e-01 | Time: 98.9362s
# L-BFGS Step 43: Total Loss: 1.474893e-02 | PDE: 3.262371e-03 | BC_sides: 0.000000e+00 | Free_top: 7.703428e-04 | Free_bot: 6.033250e-03 | Load: 4.147546e-03 | FEM MAE: 2.294546e-01 | Time: 100.0960s
# L-BFGS Step 44: Total Loss: 1.448243e-02 | PDE: 3.179250e-03 | BC_sides: 0.000000e+00 | Free_top: 7.863846e-04 | Free_bot: 5.852506e-03 | Load: 4.176214e-03 | FEM MAE: 2.289388e-01 | Time: 98.7147s
# L-BFGS Step 45: Total Loss: 1.425471e-02 | PDE: 3.210753e-03 | BC_sides: 0.000000e+00 | Free_top: 8.137940e-04 | Free_bot: 5.581198e-03 | Load: 4.183120e-03 | FEM MAE: 2.276171e-01 | Time: 98.6119s
# L-BFGS Step 46: Total Loss: 1.369731e-02 | PDE: 3.240435e-03 | BC_sides: 0.000000e+00 | Free_top: 8.516088e-04 | Free_bot: 5.384975e-03 | Load: 3.777348e-03 | FEM MAE: 2.264669e-01 | Time: 98.7397s
# L-BFGS Step 47: Total Loss: 1.366383e-02 | PDE: 3.258335e-03 | BC_sides: 0.000000e+00 | Free_top: 8.587496e-04 | Free_bot: 5.258902e-03 | Load: 3.825080e-03 | FEM MAE: 2.256377e-01 | Time: 97.4584s
# L-BFGS Step 48: Total Loss: 1.314211e-02 | PDE: 3.217530e-03 | BC_sides: 0.000000e+00 | Free_top: 9.182827e-04 | Free_bot: 5.034779e-03 | Load: 3.524882e-03 | FEM MAE: 2.243701e-01 | Time: 102.7423s
# L-BFGS Step 49: Total Loss: 1.270527e-02 | PDE: 3.129860e-03 | BC_sides: 0.000000e+00 | Free_top: 9.257835e-04 | Free_bot: 4.790712e-03 | Load: 3.450398e-03 | FEM MAE: 2.232233e-01 | Time: 102.8522s
# L-BFGS Step 50: Total Loss: 1.263464e-02 | PDE: 3.132534e-03 | BC_sides: 0.000000e+00 | Free_top: 9.793480e-04 | Free_bot: 4.783690e-03 | Load: 3.389214e-03 | FEM MAE: 2.224940e-01 | Time: 97.0592s
# L-BFGS Step 51: Total Loss: 1.236054e-02 | PDE: 3.024851e-03 | BC_sides: 0.000000e+00 | Free_top: 9.440408e-04 | Free_bot: 4.682102e-03 | Load: 3.391142e-03 | FEM MAE: 2.226360e-01 | Time: 97.1193s
# L-BFGS Step 52: Total Loss: 1.222954e-02 | PDE: 3.062755e-03 | BC_sides: 0.000000e+00 | Free_top: 9.501131e-04 | Free_bot: 4.658239e-03 | Load: 3.267628e-03 | FEM MAE: 2.227134e-01 | Time: 96.5175s
# L-BFGS Step 53: Total Loss: 1.229303e-02 | PDE: 3.079147e-03 | BC_sides: 0.000000e+00 | Free_top: 9.812275e-04 | Free_bot: 4.713369e-03 | Load: 3.237433e-03 | FEM MAE: 2.226890e-01 | Time: 96.1929s
# L-BFGS Step 54: Total Loss: 1.209648e-02 | PDE: 3.034263e-03 | BC_sides: 0.000000e+00 | Free_top: 9.799026e-04 | Free_bot: 4.543246e-03 | Load: 3.201265e-03 | FEM MAE: 2.217928e-01 | Time: 104.2838s
# L-BFGS Step 55: Total Loss: 1.197010e-02 | PDE: 3.004178e-03 | BC_sides: 0.000000e+00 | Free_top: 9.735296e-04 | Free_bot: 4.455625e-03 | Load: 3.213132e-03 | FEM MAE: 2.218508e-01 | Time: 99.1881s
# L-BFGS Step 56: Total Loss: 1.185717e-02 | PDE: 2.997509e-03 | BC_sides: 0.000000e+00 | Free_top: 9.832612e-04 | Free_bot: 4.384046e-03 | Load: 3.218936e-03 | FEM MAE: 2.209543e-01 | Time: 99.2095s
# L-BFGS Step 57: Total Loss: 1.167961e-02 | PDE: 3.036731e-03 | BC_sides: 0.000000e+00 | Free_top: 9.974543e-04 | Free_bot: 4.329280e-03 | Load: 3.192840e-03 | FEM MAE: 2.208055e-01 | Time: 44.3393s
# L-BFGS Step 58: Total Loss: 1.167275e-02 | PDE: 3.089189e-03 | BC_sides: 0.000000e+00 | Free_top: 1.006890e-03 | Free_bot: 4.391802e-03 | Load: 3.039093e-03 | FEM MAE: 2.210724e-01 | Time: 40.2831s
# L-BFGS Step 59: Total Loss: 1.168659e-02 | PDE: 3.090385e-03 | BC_sides: 0.000000e+00 | Free_top: 1.025607e-03 | Free_bot: 4.332489e-03 | Load: 3.066375e-03 | FEM MAE: 2.211074e-01 | Time: 73.5166s
# L-BFGS Step 60: Total Loss: 1.174482e-02 | PDE: 3.097632e-03 | BC_sides: 0.000000e+00 | Free_top: 1.017441e-03 | Free_bot: 4.363402e-03 | Load: 3.144465e-03 | FEM MAE: 2.209645e-01 | Time: 27.1512s
# L-BFGS Step 61: Total Loss: 1.160952e-02 | PDE: 3.011563e-03 | BC_sides: 0.000000e+00 | Free_top: 1.023693e-03 | Free_bot: 4.320009e-03 | Load: 3.149185e-03 | FEM MAE: 2.213276e-01 | Time: 46.1293s
# L-BFGS Step 62: Total Loss: 1.160566e-02 | PDE: 3.018631e-03 | BC_sides: 0.000000e+00 | Free_top: 1.074032e-03 | Free_bot: 4.320782e-03 | Load: 3.062173e-03 | FEM MAE: 2.212092e-01 | Time: 51.8768s
# L-BFGS Step 63: Total Loss: 1.144142e-02 | PDE: 3.013682e-03 | BC_sides: 0.000000e+00 | Free_top: 9.976028e-04 | Free_bot: 4.266868e-03 | Load: 3.050757e-03 | FEM MAE: 2.212362e-01 | Time: 44.9383s
# L-BFGS Step 64: Total Loss: 1.149587e-02 | PDE: 3.017600e-03 | BC_sides: 0.000000e+00 | Free_top: 1.048435e-03 | Free_bot: 4.339648e-03 | Load: 2.991388e-03 | FEM MAE: 2.210743e-01 | Time: 42.6937s
# L-BFGS Step 65: Total Loss: 1.164238e-02 | PDE: 3.005641e-03 | BC_sides: 0.000000e+00 | Free_top: 1.047587e-03 | Free_bot: 4.374534e-03 | Load: 3.128896e-03 | FEM MAE: 2.210294e-01 | Time: 26.3468s
# L-BFGS Step 66: Total Loss: 1.178566e-02 | PDE: 3.083053e-03 | BC_sides: 0.000000e+00 | Free_top: 9.908273e-04 | Free_bot: 4.430146e-03 | Load: 3.205188e-03 | FEM MAE: 2.210809e-01 | Time: 17.4885s
# L-BFGS Step 67: Total Loss: 1.127045e-02 | PDE: 2.991042e-03 | BC_sides: 0.000000e+00 | Free_top: 1.014283e-03 | Free_bot: 4.094587e-03 | Load: 3.083904e-03 | FEM MAE: 2.210490e-01 | Time: 22.1488s
# L-BFGS Step 68: Total Loss: 1.119375e-02 | PDE: 2.932398e-03 | BC_sides: 0.000000e+00 | Free_top: 1.033955e-03 | Free_bot: 4.096251e-03 | Load: 3.045740e-03 | FEM MAE: 2.207530e-01 | Time: 24.9403s
# L-BFGS Step 69: Total Loss: 1.130547e-02 | PDE: 2.965567e-03 | BC_sides: 0.000000e+00 | Free_top: 1.029134e-03 | Free_bot: 4.184559e-03 | Load: 3.030501e-03 | FEM MAE: 2.205680e-01 | Time: 24.5023s
# L-BFGS Step 70: Total Loss: 1.138757e-02 | PDE: 2.915597e-03 | BC_sides: 0.000000e+00 | Free_top: 1.022620e-03 | Free_bot: 4.325809e-03 | Load: 3.008737e-03 | FEM MAE: 2.206940e-01 | Time: 38.4736s
# L-BFGS Step 71: Total Loss: 1.127968e-02 | PDE: 2.888775e-03 | BC_sides: 0.000000e+00 | Free_top: 1.018660e-03 | Free_bot: 4.242324e-03 | Load: 3.011841e-03 | FEM MAE: 2.208278e-01 | Time: 42.5932s
# L-BFGS Step 72: Total Loss: 1.132239e-02 | PDE: 2.943337e-03 | BC_sides: 0.000000e+00 | Free_top: 1.015873e-03 | Free_bot: 4.261539e-03 | Load: 3.002900e-03 | FEM MAE: 2.208643e-01 | Time: 33.4999s
# L-BFGS Step 73: Total Loss: 1.129565e-02 | PDE: 2.996618e-03 | BC_sides: 0.000000e+00 | Free_top: 1.046614e-03 | Free_bot: 4.249636e-03 | Load: 2.929791e-03 | FEM MAE: 2.206627e-01 | Time: 23.7954s
# L-BFGS Step 74: Total Loss: 1.139133e-02 | PDE: 2.957096e-03 | BC_sides: 0.000000e+00 | Free_top: 1.043079e-03 | Free_bot: 4.245015e-03 | Load: 3.066146e-03 | FEM MAE: 2.207668e-01 | Time: 25.4440s
# L-BFGS Step 75: Total Loss: 1.136983e-02 | PDE: 2.906671e-03 | BC_sides: 0.000000e+00 | Free_top: 1.052316e-03 | Free_bot: 4.259213e-03 | Load: 3.109626e-03 | FEM MAE: 2.207752e-01 | Time: 13.9033s
# L-BFGS Step 76: Total Loss: 1.124734e-02 | PDE: 2.861316e-03 | BC_sides: 0.000000e+00 | Free_top: 1.007385e-03 | Free_bot: 4.230096e-03 | Load: 3.043876e-03 | FEM MAE: 2.208526e-01 | Time: 46.1321s
# L-BFGS Step 77: Total Loss: 1.136668e-02 | PDE: 2.942491e-03 | BC_sides: 0.000000e+00 | Free_top: 1.021515e-03 | Free_bot: 4.273387e-03 | Load: 3.060591e-03 | FEM MAE: 2.208176e-01 | Time: 15.4742s
# L-BFGS Step 78: Total Loss: 1.125534e-02 | PDE: 2.935073e-03 | BC_sides: 0.000000e+00 | Free_top: 1.011620e-03 | Free_bot: 4.235059e-03 | Load: 2.991391e-03 | FEM MAE: 2.209101e-01 | Time: 35.6040s
# L-BFGS Step 79: Total Loss: 1.137220e-02 | PDE: 2.927993e-03 | BC_sides: 0.000000e+00 | Free_top: 1.007851e-03 | Free_bot: 4.155007e-03 | Load: 3.182678e-03 | FEM MAE: 2.207020e-01 | Time: 35.6320s
# L-BFGS Step 80: Total Loss: 1.139097e-02 | PDE: 2.945598e-03 | BC_sides: 0.000000e+00 | Free_top: 1.021598e-03 | Free_bot: 4.202225e-03 | Load: 3.162061e-03 | FEM MAE: 2.206381e-01 | Time: 17.6603s
# L-BFGS Step 81: Total Loss: 1.150286e-02 | PDE: 3.002896e-03 | BC_sides: 0.000000e+00 | Free_top: 1.027887e-03 | Free_bot: 4.258898e-03 | Load: 3.153467e-03 | FEM MAE: 2.205185e-01 | Time: 17.2317s
# L-BFGS Step 82: Total Loss: 1.136000e-02 | PDE: 2.947963e-03 | BC_sides: 0.000000e+00 | Free_top: 1.009641e-03 | Free_bot: 4.205489e-03 | Load: 3.151746e-03 | FEM MAE: 2.206465e-01 | Time: 9.3877s
# L-BFGS Step 83: Total Loss: 1.125168e-02 | PDE: 2.981557e-03 | BC_sides: 0.000000e+00 | Free_top: 9.968232e-04 | Free_bot: 4.205538e-03 | Load: 3.003457e-03 | FEM MAE: 2.207711e-01 | Time: 15.1906s
# L-BFGS Step 84: Total Loss: 1.147037e-02 | PDE: 3.001324e-03 | BC_sides: 0.000000e+00 | Free_top: 9.479875e-04 | Free_bot: 4.285266e-03 | Load: 3.154068e-03 | FEM MAE: 2.208093e-01 | Time: 27.1592s
# L-BFGS Step 85: Total Loss: 1.145586e-02 | PDE: 3.007543e-03 | BC_sides: 0.000000e+00 | Free_top: 9.765488e-04 | Free_bot: 4.306585e-03 | Load: 3.073506e-03 | FEM MAE: 2.204428e-01 | Time: 30.3527s
# L-BFGS Step 86: Total Loss: 1.149363e-02 | PDE: 3.027185e-03 | BC_sides: 0.000000e+00 | Free_top: 9.959318e-04 | Free_bot: 4.264654e-03 | Load: 3.130749e-03 | FEM MAE: 2.205986e-01 | Time: 18.4072s
# L-BFGS Step 87: Total Loss: 1.127362e-02 | PDE: 3.002839e-03 | BC_sides: 0.000000e+00 | Free_top: 9.767680e-04 | Free_bot: 4.228435e-03 | Load: 2.998527e-03 | FEM MAE: 2.208471e-01 | Time: 24.1807s
# L-BFGS Step 88: Total Loss: 1.138946e-02 | PDE: 2.962192e-03 | BC_sides: 0.000000e+00 | Free_top: 9.588434e-04 | Free_bot: 4.325185e-03 | Load: 3.069745e-03 | FEM MAE: 2.205963e-01 | Time: 18.7520s
# L-BFGS Step 89: Total Loss: 1.147141e-02 | PDE: 3.029604e-03 | BC_sides: 0.000000e+00 | Free_top: 9.667783e-04 | Free_bot: 4.203839e-03 | Load: 3.174665e-03 | FEM MAE: 2.207447e-01 | Time: 32.4968s
# L-BFGS Step 90: Total Loss: 1.133913e-02 | PDE: 2.957754e-03 | BC_sides: 0.000000e+00 | Free_top: 9.974989e-04 | Free_bot: 4.176160e-03 | Load: 3.122333e-03 | FEM MAE: 2.205216e-01 | Time: 31.9464s
# L-BFGS Step 91: Total Loss: 1.132290e-02 | PDE: 2.974935e-03 | BC_sides: 0.000000e+00 | Free_top: 1.020812e-03 | Free_bot: 4.090385e-03 | Load: 3.174731e-03 | FEM MAE: 2.207005e-01 | Time: 21.1430s
# L-BFGS Step 92: Total Loss: 1.116676e-02 | PDE: 2.916366e-03 | BC_sides: 0.000000e+00 | Free_top: 1.018545e-03 | Free_bot: 4.093291e-03 | Load: 3.070208e-03 | FEM MAE: 2.203472e-01 | Time: 25.4535s
# L-BFGS Step 93: Total Loss: 1.122408e-02 | PDE: 2.927161e-03 | BC_sides: 0.000000e+00 | Free_top: 1.017170e-03 | Free_bot: 4.145859e-03 | Load: 3.077201e-03 | FEM MAE: 2.205226e-01 | Time: 14.1341s
# L-BFGS Step 94: Total Loss: 1.119062e-02 | PDE: 2.893380e-03 | BC_sides: 0.000000e+00 | Free_top: 1.029039e-03 | Free_bot: 4.175088e-03 | Load: 3.024699e-03 | FEM MAE: 2.204132e-01 | Time: 22.2876s
# L-BFGS Step 95: Total Loss: 1.117246e-02 | PDE: 2.868961e-03 | BC_sides: 0.000000e+00 | Free_top: 1.008181e-03 | Free_bot: 4.204181e-03 | Load: 3.020312e-03 | FEM MAE: 2.203635e-01 | Time: 21.2658s
# L-BFGS Step 96: Total Loss: 1.130706e-02 | PDE: 2.903843e-03 | BC_sides: 0.000000e+00 | Free_top: 1.040967e-03 | Free_bot: 4.292627e-03 | Load: 2.972785e-03 | FEM MAE: 2.202557e-01 | Time: 29.8492s
# L-BFGS Step 97: Total Loss: 1.128047e-02 | PDE: 2.905208e-03 | BC_sides: 0.000000e+00 | Free_top: 9.844734e-04 | Free_bot: 4.312414e-03 | Load: 2.994722e-03 | FEM MAE: 2.204094e-01 | Time: 29.0259s
# L-BFGS Step 98: Total Loss: 1.118129e-02 | PDE: 2.903088e-03 | BC_sides: 0.000000e+00 | Free_top: 9.819508e-04 | Free_bot: 4.160166e-03 | Load: 3.047398e-03 | FEM MAE: 2.205115e-01 | Time: 34.5179s
# L-BFGS Step 99: Total Loss: 1.123063e-02 | PDE: 2.951930e-03 | BC_sides: 0.000000e+00 | Free_top: 9.269904e-04 | Free_bot: 4.251257e-03 | Load: 3.025014e-03 | FEM MAE: 2.204440e-01 | Time: 22.0303s
# Model saved.
# MultiLayerPINN(
#   (layer): LayerNet(
#     (net): Sequential(
#       (0): Linear(in_features=3, out_features=32, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=32, out_features=32, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=32, out_features=3, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Visualize Training Data Distribution
#
# Show the spatial distribution of collocation points used for training.

# %%
# Generate a sample of training data
import data as data_module
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

training_data = data_module.get_data()

# Extract different types of collocation points
interior = training_data['interior'][0].numpy()
bc_sides = training_data['sides'][0].numpy()
top_load = training_data['top_load'].numpy()
top_free = training_data['top_free'].numpy()
bottom = training_data['bottom'].numpy()

print("Training Data Statistics:")
print(f"  Interior points: {interior.shape[0]}")
print(f"  BC Sides points: {bc_sides.shape[0]}")
print(f"  Top Load patch: {top_load.shape[0]}")
print(f"  Top Free surface: {top_free.shape[0]}")
print(f"  Bottom surface: {bottom.shape[0]}")
print(f"  Total: {interior.shape[0] + bc_sides.shape[0] + top_load.shape[0] + top_free.shape[0] + bottom.shape[0]}")

# Create 3D visualization
fig = plt.figure(figsize=(18, 12))

# 3D view
ax1 = fig.add_subplot(2, 2, 1, projection='3d')
ax1.scatter(interior[:, 0], interior[:, 1], interior[:, 2], c='gray', alpha=0.3, s=1, label='Interior')
ax1.scatter(bc_sides[:, 0], bc_sides[:, 1], bc_sides[:, 2], c='blue', alpha=0.6, s=3, label='BC Sides')
ax1.scatter(top_load[:, 0], top_load[:, 1], top_load[:, 2], c='red', alpha=0.8, s=5, label='Top Load')
ax1.scatter(top_free[:, 0], top_free[:, 1], top_free[:, 2], c='cyan', alpha=0.6, s=3, label='Top Free')
ax1.scatter(bottom[:, 0], bottom[:, 1], bottom[:, 2], c='purple', alpha=0.6, s=3, label='Bottom')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_zlabel('z')
ax1.set_title('3D Distribution of Collocation Points', fontsize=14)
ax1.legend(loc='upper right', fontsize=8)
ax1.view_init(elev=20, azim=45)

# Top view (x-y plane)
ax2 = fig.add_subplot(2, 2, 2)
ax2.scatter(interior[:, 0], interior[:, 1], c='gray', alpha=0.2, s=1, label='Interior')
ax2.scatter(bc_sides[:, 0], bc_sides[:, 1], c='blue', alpha=0.5, s=3, label='BC Sides')
ax2.scatter(top_load[:, 0], top_load[:, 1], c='red', alpha=0.8, s=5, label='Top Load')
ax2.scatter(top_free[:, 0], top_free[:, 1], c='cyan', alpha=0.5, s=3, label='Top Free')
ax2.scatter(bottom[:, 0], bottom[:, 1], c='purple', alpha=0.3, s=3, label='Bottom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('Top View (x-y plane)', fontsize=14)
ax2.legend(loc='upper right', fontsize=8)
ax2.set_aspect('equal')
ax2.grid(True, alpha=0.3)

# Side view (x-z plane)
ax3 = fig.add_subplot(2, 2, 3)
ax3.scatter(interior[:, 0], interior[:, 2], c='gray', alpha=0.3, s=1, label='Interior')
ax3.scatter(bc_sides[:, 0], bc_sides[:, 2], c='blue', alpha=0.6, s=3, label='BC Sides')
ax3.scatter(top_load[:, 0], top_load[:, 2], c='red', alpha=0.8, s=5, label='Top Load')
ax3.scatter(top_free[:, 0], top_free[:, 2], c='cyan', alpha=0.6, s=3, label='Top Free')
ax3.scatter(bottom[:, 0], bottom[:, 2], c='purple', alpha=0.6, s=3, label='Bottom')
ax3.set_xlabel('x')
ax3.set_ylabel('z')
ax3.set_title('Side View (x-z plane)', fontsize=14)
ax3.legend(loc='upper right', fontsize=8)
ax3.grid(True, alpha=0.3)

# Front view (y-z plane)
ax4 = fig.add_subplot(2, 2, 4)
ax4.scatter(interior[:, 1], interior[:, 2], c='gray', alpha=0.3, s=1, label='Interior')
ax4.scatter(bc_sides[:, 1], bc_sides[:, 2], c='blue', alpha=0.6, s=3, label='BC Sides')
ax4.scatter(top_load[:, 1], top_load[:, 2], c='red', alpha=0.8, s=5, label='Top Load')
ax4.scatter(top_free[:, 1], top_free[:, 2], c='cyan', alpha=0.6, s=3, label='Top Free')
ax4.scatter(bottom[:, 1], bottom[:, 2], c='purple', alpha=0.6, s=3, label='Bottom')
ax4.set_xlabel('y')
ax4.set_ylabel('z')
ax4.set_title('Front View (y-z plane)', fontsize=14)
ax4.legend(loc='upper right', fontsize=8)
ax4.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("training_data_distribution.png", dpi=150)
print("\nSaved training_data_distribution.png")
plt.show()
# Out:
# Training Data Statistics:
#   Interior points: 10000
#   BC Sides points: 2000
#   Top Load patch: 2000
#   Top Free surface: 2000
#   Bottom surface: 2000
#   Total: 18000
#
# Saved training_data_distribution.png

# %% [markdown]
# # Training Loss History
#
# Visualize the loss evolution during training.

# %%
# Load and plot training history
import numpy as np
import matplotlib.pyplot as plt

loss_history = np.load("loss_history.npy", allow_pickle=True).item()
soap_history = loss_history['soap']
lbfgs_history = loss_history['lbfgs']

# Combine for total view
n_soap = len(soap_history['total'])
n_lbfgs = len(lbfgs_history['total'])
total_steps = n_soap + n_lbfgs

# Concatenate for plotting
def concat_losses(key):
    return np.concatenate([soap_history[key], lbfgs_history[key]])

# Check if FEM error data is available
has_fem_error = len(soap_history.get('fem_mae', [])) > 0

if has_fem_error:
    fig, axes = plt.subplots(2, 3, figsize=(20, 12))
    axes = axes.flatten()
else:
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    axes = axes.flatten()

# Top left: Total loss
total_loss = concat_losses('total')
axes[0].plot(total_loss, linewidth=1.5)
axes[0].axvline(x=n_soap, color='r', linestyle='--', label='Switch to L-BFGS')
axes[0].set_xlabel("Training Step", fontsize=12)
axes[0].set_ylabel("Total Loss", fontsize=12)
axes[0].set_title("Total Loss", fontsize=14)
axes[0].set_yscale('log')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Top middle: PDE loss
pde_loss = concat_losses('pde')
axes[1].plot(pde_loss, linewidth=1.5, color='green')
axes[1].axvline(x=n_soap, color='r', linestyle='--', alpha=0.5)
axes[1].set_xlabel("Training Step", fontsize=12)
axes[1].set_ylabel("PDE Loss", fontsize=12)
axes[1].set_title("PDE Loss", fontsize=14)
axes[1].set_yscale('log')
axes[1].grid(True, alpha=0.3)

# Top right: Boundary condition losses
bc_sides_loss = concat_losses('bc_sides')
free_top_loss = concat_losses('free_top')
free_bot_loss = concat_losses('free_bot')
axes[2].plot(bc_sides_loss, linewidth=1.5, label='BC Sides', color='blue')
axes[2].plot(free_top_loss, linewidth=1.5, label='Free Top', color='cyan')
axes[2].plot(free_bot_loss, linewidth=1.5, label='Free Bot', color='purple')
axes[2].axvline(x=n_soap, color='r', linestyle='--', alpha=0.5)
axes[2].set_xlabel("Training Step", fontsize=12)
axes[2].set_ylabel("BC Loss", fontsize=12)
axes[2].set_title("Boundary Condition Losses", fontsize=14)
axes[2].set_yscale('log')
axes[2].legend()
axes[2].grid(True, alpha=0.3)

# Bottom left: Load loss
load_loss = concat_losses('load')
axes[3].plot(load_loss, linewidth=1.5, color='red')
axes[3].axvline(x=n_soap, color='r', linestyle='--', alpha=0.5)
axes[3].set_xlabel("Training Step", fontsize=12)
axes[3].set_ylabel("Load Loss", fontsize=12)
axes[3].set_title("Load BC Loss", fontsize=14)
axes[3].set_yscale('log')
axes[3].grid(True, alpha=0.3)

# FEM error plots (if available)
if has_fem_error:
    # Bottom middle: FEM MAE
    soap_fem_epochs = soap_history['epochs']
    soap_fem_mae = soap_history['fem_mae']
    lbfgs_fem_steps = [n_soap + s for s in lbfgs_history['steps']]
    lbfgs_fem_mae = lbfgs_history['fem_mae']
    
    axes[4].plot(soap_fem_epochs, soap_fem_mae, 'o-', linewidth=1.5, label='SOAP', color='blue')
    axes[4].plot(lbfgs_fem_steps, lbfgs_fem_mae, 's-', linewidth=1.5, label='L-BFGS', color='orange')
    axes[4].axvline(x=n_soap, color='r', linestyle='--', alpha=0.5)
    axes[4].set_xlabel("Training Step", fontsize=12)
    axes[4].set_ylabel("FEM MAE", fontsize=12)
    axes[4].set_title("FEM Mean Absolute Error", fontsize=14)
    axes[4].set_yscale('log')
    axes[4].legend()
    axes[4].grid(True, alpha=0.3)
    
    # Bottom right: FEM Max Error
    soap_fem_max = soap_history['fem_max_err']
    lbfgs_fem_max = lbfgs_history['fem_max_err']
    
    axes[5].plot(soap_fem_epochs, soap_fem_max, 'o-', linewidth=1.5, label='SOAP', color='blue')
    axes[5].plot(lbfgs_fem_steps, lbfgs_fem_max, 's-', linewidth=1.5, label='L-BFGS', color='orange')
    axes[5].axvline(x=n_soap, color='r', linestyle='--', alpha=0.5)
    axes[5].set_xlabel("Training Step", fontsize=12)
    axes[5].set_ylabel("FEM Max Error", fontsize=12)
    axes[5].set_title("FEM Maximum Error", fontsize=14)
    axes[5].set_yscale('log')
    axes[5].legend()
    axes[5].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("training_history.png", dpi=150)

print(f"Training completed in {total_steps} steps")
print(f"  SOAP phase: {n_soap} epochs")
print(f"  L-BFGS phase: {n_lbfgs} steps")
print(f"\nFinal losses (after L-BFGS):")
print(f"  Total: {lbfgs_history['total'][-1]:.6e}")
print(f"  PDE: {lbfgs_history['pde'][-1]:.6e}")
print(f"  BC Sides: {lbfgs_history['bc_sides'][-1]:.6e}")
print(f"  Free Top: {lbfgs_history['free_top'][-1]:.6e}")
print(f"  Free Bot: {lbfgs_history['free_bot'][-1]:.6e} ← Check this!")
print(f"  Load: {lbfgs_history['load'][-1]:.6e}")
if has_fem_error:
    print(f"  FEM MAE: {lbfgs_history['fem_mae'][-1]:.6e}")
    print(f"  FEM Max Error: {lbfgs_history['fem_max_err'][-1]:.6e}")
print(f"\nAfter Adam phase:")
print(f"  Total: {soap_history['total'][-1]:.6e}")
print(f"  Free Bot: {soap_history['free_bot'][-1]:.6e}")
if has_fem_error and len(soap_history['fem_mae']) > 0:
    print(f"  FEM MAE: {soap_history['fem_mae'][-1]:.6e}")
print(f"\nInitial total loss: {soap_history['total'][0]:.6e}")
print(f"Final reduction: {soap_history['total'][0] / lbfgs_history['total'][-1]:.2f}x")
print("\nSaved training_history.png")
plt.show()
# Out:
# Training completed in 2100 steps
#   SOAP phase: 2000 epochs
#   L-BFGS phase: 100 steps
#
# Final losses (after L-BFGS):
#   Total: 1.123063e-02
#   PDE: 2.951930e-03
#   BC Sides: 0.000000e+00
#   Free Top: 9.269904e-04
#   Free Bot: 4.251257e-03 ← Check this!
#   Load: 3.025014e-03
#   FEM MAE: 2.204440e-01
#   FEM Max Error: 2.155741e+00
#
# After SOAP phase:
#   Total: 7.423513e-02
#   Free Bot: 6.016040e-03
#   FEM MAE: 2.624946e-01
#
# Initial total loss: 8.704504e+01
# Final reduction: 7750.68x
#
# Saved training_history.png

# %% [markdown]
# # Compare PINN and FEM Solutions
#
# Load and compare the results from both methods.

# %%
# Now compare PINN and FEM
import numpy as np
import matplotlib.pyplot as plt
import torch
import pinn_config as config
import model

print("Loading FEA Solution...")
data = np.load("fea_solution.npy", allow_pickle=True).item()
X_fea = data['x']
Y_fea = data['y']
Z_fea = data['z']
U_fea = data['u']

print(f"FEA Grid: {X_fea.shape}")

# Load PINN model
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

pinn = model.MultiLayerPINN().to(device)
pinn.load_state_dict(torch.load("pinn_model.pth", map_location=device, weights_only=True))
pinn.eval()
print("PINN model loaded")

# Evaluate PINN on FEM grid
pts = np.stack([X_fea.ravel(), Y_fea.ravel(), Z_fea.ravel()], axis=1)
U_pinn_flat = np.zeros_like(pts)

with torch.no_grad():
    pts_tensor = torch.tensor(pts, dtype=torch.float32).to(device)
    U_pinn_flat = pinn(pts_tensor, 0).cpu().numpy()

U_pinn = U_pinn_flat.reshape(U_fea.shape)
print("PINN predictions computed")
# Out:
# Loading FEA Solution...
# FEA Grid: (31, 31, 11)
# PINN model loaded
# PINN predictions computed

# %%
# Compute comparison metrics on top surface
u_z_fea_top = U_fea[:, :, -1, 2]
u_z_pinn_top = U_pinn[:, :, -1, 2]

abs_diff = np.abs(u_z_fea_top - u_z_pinn_top)
mae = np.mean(abs_diff)
max_err = np.max(abs_diff)
denom = np.max(np.abs(u_z_fea_top))
mae_pct = (mae / denom) * 100.0 if denom > 0 else 0.0

print(f"\n{'='*50}")
print(f"Comparison Results (Top Surface u_z):")
print(f"{'='*50}")
print(f"MAE: {mae:.6f}")
print(f"MAE % of max |FEA u_z|: {mae_pct:.2f}%")
print(f"Max Error: {max_err:.6f}")
print(f"Peak Deflection FEA: {u_z_fea_top.min():.6f}")
print(f"Peak Deflection PINN: {u_z_pinn_top.min():.6f}")
print(f"{'='*50}")
# Out:
# ==================================================
# Comparison Results (Top Surface u_z):
# ==================================================
# MAE: 0.558774
# MAE % of max |FEA u_z|: 18.92%
# Max Error: 2.121598
# Peak Deflection FEA: -2.953146
# Peak Deflection PINN: -0.831548
# ==================================================

# %%
# Visualize comparison - Top surface
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# FEA
c1 = axes[0].contourf(X_fea[:,:,0], Y_fea[:,:,0], u_z_fea_top, levels=50, cmap='jet')
axes[0].set_title("FEA Displacement u_z (Top)", fontsize=14)
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")
plt.colorbar(c1, ax=axes[0])

# PINN
c2 = axes[1].contourf(X_fea[:,:,0], Y_fea[:,:,0], u_z_pinn_top, levels=50, cmap='jet')
axes[1].set_title("PINN Displacement u_z (Top)", fontsize=14)
axes[1].set_xlabel("x")
axes[1].set_ylabel("y")
plt.colorbar(c2, ax=axes[1])

# Error
c3 = axes[2].contourf(X_fea[:,:,0], Y_fea[:,:,0], abs_diff, levels=50, cmap='magma')
axes[2].set_title("Absolute Error |FEA - PINN|", fontsize=14)
axes[2].set_xlabel("x")
axes[2].set_ylabel("y")
plt.colorbar(c3, ax=axes[2])

plt.tight_layout()
plt.savefig("comparison_top.png", dpi=150)
print("Saved comparison_top.png")
plt.show()
# Out:
# Saved comparison_top.png

# %%
# Visualize cross-section (x-z plane at mid-y)
mid_y = U_fea.shape[1] // 2

xz_X = X_fea[:, mid_y, :]
xz_Z = Z_fea[:, mid_y, :]
xz_Uz_fea = U_fea[:, mid_y, :, 2]
xz_Uz_pinn = U_pinn[:, mid_y, :, 2]

fig2, axes2 = plt.subplots(1, 2, figsize=(15, 6))

c4 = axes2[0].contourf(xz_X, xz_Z, xz_Uz_fea, levels=50, cmap='jet')
axes2[0].set_title("FEA Cross Section u_z (x-z plane)", fontsize=14)
axes2[0].set_xlabel("x")
axes2[0].set_ylabel("z")
plt.colorbar(c4, ax=axes2[0])

c5 = axes2[1].contourf(xz_X, xz_Z, xz_Uz_pinn, levels=50, cmap='jet')
axes2[1].set_title("PINN Cross Section u_z (x-z plane)", fontsize=14)
axes2[1].set_xlabel("x")
axes2[1].set_ylabel("z")
plt.colorbar(c5, ax=axes2[1])

plt.tight_layout()
plt.savefig("comparison_cross_section.png", dpi=150)
print("Saved comparison_cross_section.png")
plt.show()
# Out:
# Saved comparison_cross_section.png

# %% [markdown]
# # Visualize PDE Residuals
#
# Check how well the PINN satisfies the equilibrium equations.

# %%
# Compute PDE residual on x-z plane at mid-y
import physics

# Sample points on x-z plane
nx_res, nz_res = 50, 20
x_res = np.linspace(0, 1.0, nx_res)
z_res = np.linspace(0, 0.1, nz_res)
y_mid = 0.5

X_res, Z_res = np.meshgrid(x_res, z_res, indexing='ij')
Y_res = np.ones_like(X_res) * y_mid

pts_res = np.stack([X_res.ravel(), Y_res.ravel(), Z_res.ravel()], axis=1)
pts_res_tensor = torch.tensor(pts_res, dtype=torch.float32, requires_grad=True).to(device)

# Get Lame parameters
lm, mu = config.Lame_Params[0]

# Compute displacement
u = pinn(pts_res_tensor, 0)

# Compute gradients and stress
grad_u = physics.gradient(u, pts_res_tensor)
eps = physics.strain(grad_u)
sig = physics.stress(eps, lm, mu)

# Compute divergence (PDE residual)
div_sigma = physics.divergence(sig, pts_res_tensor)
residual = -div_sigma  # Equilibrium: -div(sigma) = 0

# Convert to numpy and compute magnitude
residual_np = residual.detach().cpu().numpy()
residual_mag = np.sqrt(np.sum(residual_np**2, axis=1))
residual_mag_grid = residual_mag.reshape(X_res.shape)

print(f"PDE Residual Statistics (x-z plane):")
print(f"  Mean: {residual_mag.mean():.6e}")
print(f"  Max: {residual_mag.max():.6e}")
print(f"  Min: {residual_mag.min():.6e}")
# Out:
# PDE Residual Statistics (x-z plane):
#   Mean: 8.307832e-02
#   Max: 3.256761e-01
#   Min: 6.117504e-03

# %%
# Plot PDE residual magnitude
fig, ax = plt.subplots(1, 1, figsize=(10, 6))

c = ax.contourf(X_res, Z_res, residual_mag_grid, levels=50, cmap='viridis')
ax.set_title("PDE Residual Magnitude |−∇·σ| (x-z plane at y=0.5)", fontsize=14)
ax.set_xlabel("x")
ax.set_ylabel("z")
cbar = plt.colorbar(c, ax=ax)
cbar.set_label("Residual Magnitude")

plt.tight_layout()
plt.savefig("pde_residual_xz.png", dpi=150)
print("Saved pde_residual_xz.png")
plt.show()
# Out:
# Saved pde_residual_xz.png

# %%
# Plot individual components of PDE residual
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

residual_x = residual_np[:, 0].reshape(X_res.shape)
residual_y = residual_np[:, 1].reshape(X_res.shape)
residual_z = residual_np[:, 2].reshape(X_res.shape)

# X-component
c1 = axes[0].contourf(X_res, Z_res, residual_x, levels=50, cmap='RdBu_r')
axes[0].set_title("PDE Residual: X-component", fontsize=12)
axes[0].set_xlabel("x")
axes[0].set_ylabel("z")
plt.colorbar(c1, ax=axes[0])

# Y-component
c2 = axes[1].contourf(X_res, Z_res, residual_y, levels=50, cmap='RdBu_r')
axes[1].set_title("PDE Residual: Y-component", fontsize=12)
axes[1].set_xlabel("x")
axes[1].set_ylabel("z")
plt.colorbar(c2, ax=axes[1])

# Z-component
c3 = axes[2].contourf(X_res, Z_res, residual_z, levels=50, cmap='RdBu_r')
axes[2].set_title("PDE Residual: Z-component", fontsize=12)
axes[2].set_xlabel("x")
axes[2].set_ylabel("z")
plt.colorbar(c3, ax=axes[2])

plt.tight_layout()
plt.savefig("pde_residual_components_xz.png", dpi=150)
print("Saved pde_residual_components_xz.png")
plt.show()
# Out:
# Saved pde_residual_components_xz.png

# %% [markdown]
# # Verify Load Distribution Consistency
#
# Check if PINN and FEM are using the same soft edge load mask.

# %%
# Compare load distributions between PINN and FEM
import physics
import matplotlib.pyplot as plt

# Sample points on the top surface (entire domain)
nx_load, ny_load = 100, 100
x_load = np.linspace(0, 1.0, nx_load)
y_load = np.linspace(0, 1.0, ny_load)
X_load, Y_load = np.meshgrid(x_load, y_load, indexing='ij')
Z_load = np.ones_like(X_load) * 0.1  # Top surface

# Create points tensor for PINN mask
pts_load = np.stack([X_load.ravel(), Y_load.ravel(), Z_load.ravel()], axis=1)
pts_load_tensor = torch.tensor(pts_load, dtype=torch.float32).to(device)

# Get PINN load mask
with torch.no_grad():
    pinn_mask = physics.load_mask(pts_load_tensor).cpu().numpy()
pinn_mask_grid = pinn_mask.reshape(X_load.shape)

# Compute FEM load mask (using same function logic)
def fem_load_mask(x, y):
    """Same as FEM solver load_mask function"""
    patch_x_min = 1.0/3.0
    patch_x_max = 2.0/3.0
    patch_y_min = 1.0/3.0
    patch_y_max = 2.0/3.0
    
    if x < patch_x_min or x > patch_x_max or y < patch_y_min or y > patch_y_max:
        return 0.0
    
    # Normalize to [0, 1] within patch
    x_norm = (x - patch_x_min) / (patch_x_max - patch_x_min)
    y_norm = (y - patch_y_min) / (patch_y_max - patch_y_min)
    
    # Quadratic falloff
    return 16.0 * x_norm * (1.0 - x_norm) * y_norm * (1.0 - y_norm)

# Compute FEM mask for each point
fem_mask = np.zeros_like(X_load)
for i in range(nx_load):
    for j in range(ny_load):
        fem_mask[i, j] = fem_load_mask(X_load[i, j], Y_load[i, j])

# Compute difference
mask_diff = np.abs(pinn_mask_grid - fem_mask)

# Visualize
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# PINN mask
im1 = axes[0, 0].contourf(X_load, Y_load, pinn_mask_grid, levels=50, cmap='hot')
axes[0, 0].set_title("PINN Load Mask", fontsize=14)
axes[0, 0].set_xlabel("x")
axes[0, 0].set_ylabel("y")
axes[0, 0].set_aspect('equal')
plt.colorbar(im1, ax=axes[0, 0], label='Load multiplier')

# FEM mask
im2 = axes[0, 1].contourf(X_load, Y_load, fem_mask, levels=50, cmap='hot')
axes[0, 1].set_title("FEM Load Mask", fontsize=14)
axes[0, 1].set_xlabel("x")
axes[0, 1].set_ylabel("y")
axes[0, 1].set_aspect('equal')
plt.colorbar(im2, ax=axes[0, 1], label='Load multiplier')

# Difference
im3 = axes[1, 0].contourf(X_load, Y_load, mask_diff, levels=50, cmap='viridis')
axes[1, 0].set_title("Absolute Difference |PINN - FEM|", fontsize=14)
axes[1, 0].set_xlabel("x")
axes[1, 0].set_ylabel("y")
axes[1, 0].set_aspect('equal')
plt.colorbar(im3, ax=axes[1, 0], label='Difference')

# Cross-section through center
center_idx = nx_load // 2
axes[1, 1].plot(y_load, pinn_mask_grid[center_idx, :], 'b-', linewidth=2, label='PINN')
axes[1, 1].plot(y_load, fem_mask[center_idx, :], 'r--', linewidth=2, label='FEM')
axes[1, 1].set_title("Load Profile at x=0.5 (center line)", fontsize=14)
axes[1, 1].set_xlabel("y")
axes[1, 1].set_ylabel("Load multiplier")
axes[1, 1].legend()
axes[1, 1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("load_mask_comparison.png", dpi=150)
print("Saved load_mask_comparison.png")

# Print statistics
print(f"\n{'='*60}")
print(f"Load Mask Comparison:")
print(f"{'='*60}")
print(f"PINN mask - Min: {pinn_mask_grid.min():.6f}, Max: {pinn_mask_grid.max():.6f}")
print(f"FEM mask  - Min: {fem_mask.min():.6f}, Max: {fem_mask.max():.6f}")
print(f"Difference - Mean: {mask_diff.mean():.6e}, Max: {mask_diff.max():.6e}")
print(f"\nCenter values (should be 1.0):")
print(f"  PINN: {pinn_mask_grid[nx_load//2, ny_load//2]:.6f}")
print(f"  FEM:  {fem_mask[nx_load//2, ny_load//2]:.6f}")
print(f"\nEdge values (should be 0.0):")
print(f"  PINN at (1/3, 1/2): {pinn_mask_grid[nx_load//3, ny_load//2]:.6f}")
print(f"  FEM at (1/3, 1/2):  {fem_mask[nx_load//3, ny_load//2]:.6f}")
print(f"{'='*60}")

if mask_diff.max() < 1e-10:
    print("✓ PINN and FEM are using IDENTICAL load distributions!")
else:
    print("⚠ Warning: PINN and FEM load distributions differ!")

plt.show()
# Out:
# Saved load_mask_comparison.png
#
# ============================================================
# Load Mask Comparison:
# ============================================================
# PINN mask - Min: 0.000000, Max: 0.998164
# FEM mask  - Min: 0.000000, Max: 0.998164
# Difference - Mean: 9.992354e-09, Max: 4.115099e-07
#
# Center values (should be 1.0):
#   PINN: 0.998164
#   FEM:  0.998164
#
# Edge values (should be 0.0):
#   PINN at (1/3, 1/2): 0.000000
#   FEM at (1/3, 1/2):  0.000000
# ============================================================
# ⚠ Warning: PINN and FEM load distributions differ!

# %% [markdown]
# # Visualize Traction (σ·n) on Top and Bottom Surfaces
#
# Check boundary condition enforcement on free surfaces.

# %%
# Compute traction on top surface (z=H)
nx_surf, ny_surf = 50, 50
x_surf = np.linspace(0, 1.0, nx_surf)
y_surf = np.linspace(0, 1.0, ny_surf)

X_top, Y_top = np.meshgrid(x_surf, y_surf, indexing='ij')
Z_top = np.ones_like(X_top) * 0.1  # z = H

pts_top = np.stack([X_top.ravel(), Y_top.ravel(), Z_top.ravel()], axis=1)
pts_top_tensor = torch.tensor(pts_top, dtype=torch.float32, requires_grad=True).to(device)

# Compute displacement and stress on top
u_top = pinn(pts_top_tensor, 0)
grad_u_top = physics.gradient(u_top, pts_top_tensor)
eps_top = physics.strain(grad_u_top)
sig_top = physics.stress(eps_top, lm, mu)

# Traction: T = sigma · n, where n = [0, 0, 1] for top
# T = [sigma_xz, sigma_yz, sigma_zz]
T_top = sig_top[:, :, 2].detach().cpu().numpy()
T_top_x = T_top[:, 0].reshape(X_top.shape)
T_top_y = T_top[:, 1].reshape(X_top.shape)
T_top_z = T_top[:, 2].reshape(X_top.shape)

print(f"\nTop Surface Traction Statistics:")
print(f"  T_x - Mean: {T_top[:, 0].mean():.6e}, Max: {np.abs(T_top[:, 0]).max():.6e}")
print(f"  T_y - Mean: {T_top[:, 1].mean():.6e}, Max: {np.abs(T_top[:, 1]).max():.6e}")
print(f"  T_z - Mean: {T_top[:, 2].mean():.6e}, Max: {np.abs(T_top[:, 2]).max():.6e}")
print(f"  (Expected: T_x=0, T_y=0, T_z=-1.0 on load patch, T_z=0 elsewhere)")
# Out:
# Top Surface Traction Statistics:
#   T_x - Mean: -9.801609e-04, Max: 5.335166e-02
#   T_y - Mean: 1.325282e-03, Max: 5.187170e-02
#   T_z - Mean: -2.504885e-02, Max: 9.127531e-01
#   (Expected: T_x=0, T_y=0, T_z=-1.0 on load patch, T_z=0 elsewhere)

# %%
# Compute traction on bottom surface (z=0)
Z_bot = np.zeros_like(X_top)  # z = 0

pts_bot = np.stack([X_top.ravel(), Y_top.ravel(), Z_bot.ravel()], axis=1)
pts_bot_tensor = torch.tensor(pts_bot, dtype=torch.float32, requires_grad=True).to(device)

# Compute displacement and stress on bottom
u_bot = pinn(pts_bot_tensor, 0)
grad_u_bot = physics.gradient(u_bot, pts_bot_tensor)
eps_bot = physics.strain(grad_u_bot)
sig_bot = physics.stress(eps_bot, lm, mu)

# Traction: T = sigma · n, where n = [0, 0, -1] for bottom
# T = -[sigma_xz, sigma_yz, sigma_zz]
T_bot = -sig_bot[:, :, 2].detach().cpu().numpy()
T_bot_x = T_bot[:, 0].reshape(X_top.shape)
T_bot_y = T_bot[:, 1].reshape(X_top.shape)
T_bot_z = T_bot[:, 2].reshape(X_top.shape)

print(f"\nBottom Surface Traction Statistics:")
print(f"  T_x - Mean: {T_bot[:, 0].mean():.6e}, Max: {np.abs(T_bot[:, 0]).max():.6e}")
print(f"  T_y - Mean: {T_bot[:, 1].mean():.6e}, Max: {np.abs(T_bot[:, 1]).max():.6e}")
print(f"  T_z - Mean: {T_bot[:, 2].mean():.6e}, Max: {np.abs(T_bot[:, 2]).max():.6e}")
print(f"  (Expected: T_x=0, T_y=0, T_z=0)")
# Out:
# Bottom Surface Traction Statistics:
#   T_x - Mean: 1.947937e-03, Max: 1.240095e-01
#   T_y - Mean: 1.437413e-03, Max: 1.087738e-01
#   T_z - Mean: 4.079841e-02, Max: 1.835213e-01
#   (Expected: T_x=0, T_y=0, T_z=0)

# %% [markdown]
# # Debug: Check Bottom BC Loss
#
# Verify that the bottom free surface BC is being satisfied by the trained model.

# %%
# Sample bottom surface points and compute BC loss as in training
import data as data_module

test_data = data_module.get_data()
x_bot_test = test_data['bottom'].to(device)
x_bot_test.requires_grad = True

u_bot_test = pinn(x_bot_test, 0)
grad_u_bot_test = physics.gradient(u_bot_test, x_bot_test)
eps_bot_test = physics.strain(grad_u_bot_test)
sig_bot_test = physics.stress(eps_bot_test, lm, mu)

# Bottom surface: n = (0, 0, -1)
# T = sigma · n = -sigma[:,:,2]
T_bot_test = -sig_bot_test[:, :, 2]

# Compute loss
loss_bot_test = torch.mean(T_bot_test**2)

print(f"\n{'='*50}")
print(f"Bottom Surface BC Violation Check:")
print(f"{'='*50}")
print(f"Bottom BC Loss (mean T²): {loss_bot_test.item():.6e}")
print(f"Mean |T|: {torch.mean(torch.abs(T_bot_test)).item():.6e}")
print(f"Max |T|: {torch.max(torch.abs(T_bot_test)).item():.6e}")
print(f"\nComponent-wise (should all be ≈0):")
print(f"  T_x: mean={T_bot_test[:, 0].mean().item():.6e}, max_abs={torch.abs(T_bot_test[:, 0]).max().item():.6e}")
print(f"  T_y: mean={T_bot_test[:, 1].mean().item():.6e}, max_abs={torch.abs(T_bot_test[:, 1]).max().item():.6e}")
print(f"  T_z: mean={T_bot_test[:, 2].mean().item():.6e}, max_abs={torch.abs(T_bot_test[:, 2]).max().item():.6e}")
print(f"{'='*50}")

# Check if there's actually pressure on bottom (should NOT be)
print(f"\nDirect σ_zz at bottom (should be ≈0 for free surface):")
print(f"  Mean σ_zz: {sig_bot_test[:, 2, 2].mean().item():.6e}")
print(f"  Max |σ_zz|: {torch.abs(sig_bot_test[:, 2, 2]).max().item():.6e}")
# Out:
# ==================================================
# Bottom Surface BC Violation Check:
# ==================================================
# Bottom BC Loss (mean T²): 1.818337e-03
# Mean |T|: 2.919529e-02
# Max |T|: 1.815485e-01
#
# Component-wise (should all be ≈0):
#   T_x: mean=2.551660e-05, max_abs=1.237807e-01
#   T_y: mean=1.779542e-03, max_abs=1.090629e-01
#   T_z: mean=4.019975e-02, max_abs=1.815485e-01
# ==================================================
#
# Direct σ_zz at bottom (should be ≈0 for free surface):
#   Mean σ_zz: -4.019975e-02
#   Max |σ_zz|: 1.815485e-01

# %% [markdown]
# **Analysis:**
#
# If the bottom BC loss is high (e.g., > 1e-3) and σ_zz ≈ -1 at the bottom center, this indicates the **bottom free surface BC is not being properly enforced** during training.
#
# Possible causes:
# 1. **Loss weight imbalance**: The load BC weight (5000.0) might be dominating, preventing proper bottom BC satisfaction
# 2. **Insufficient sampling**: Not enough collocation points on the bottom surface
# 3. **Training not converged**: Model hasn't learned to satisfy all BCs simultaneously
# 4. **Coordinate scaling**: The z-direction issue might be affecting gradient computation
#
# The PINN may be incorrectly "mirroring" the top pressure load to the bottom, treating it symmetrically rather than enforcing the free BC.

# %%
# Plot top surface traction components
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# T_x on top
c1 = axes[0].contourf(X_top, Y_top, T_top_x, levels=50, cmap='RdBu_r')
axes[0].set_title("Top Surface: T_x (should be ≈0)", fontsize=12)
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")
plt.colorbar(c1, ax=axes[0])

# T_y on top
c2 = axes[1].contourf(X_top, Y_top, T_top_y, levels=50, cmap='RdBu_r')
axes[1].set_title("Top Surface: T_y (should be ≈0)", fontsize=12)
axes[1].set_xlabel("x")
axes[1].set_ylabel("y")
plt.colorbar(c2, ax=axes[1])

# T_z on top
c3 = axes[2].contourf(X_top, Y_top, T_top_z, levels=50, cmap='RdBu_r')
axes[2].set_title("Top Surface: T_z (=-1.0 on patch, 0 elsewhere)", fontsize=12)
axes[2].set_xlabel("x")
axes[2].set_ylabel("y")
plt.colorbar(c3, ax=axes[2])

plt.tight_layout()
plt.savefig("traction_top_surface.png", dpi=150)
print("Saved traction_top_surface.png")
plt.show()
# Out:
# Saved traction_top_surface.png

# %%
# Plot bottom surface traction components
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# T_x on bottom
c1 = axes[0].contourf(X_top, Y_top, T_bot_x, levels=50, cmap='RdBu_r')
axes[0].set_title("Bottom Surface: T_x (should be ≈0)", fontsize=12)
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")
plt.colorbar(c1, ax=axes[0])

# T_y on bottom
c2 = axes[1].contourf(X_top, Y_top, T_bot_y, levels=50, cmap='RdBu_r')
axes[1].set_title("Bottom Surface: T_y (should be ≈0)", fontsize=12)
axes[1].set_xlabel("x")
axes[1].set_ylabel("y")
plt.colorbar(c2, ax=axes[1])

# T_z on bottom
c3 = axes[2].contourf(X_top, Y_top, T_bot_z, levels=50, cmap='RdBu_r')
axes[2].set_title("Bottom Surface: T_z (should be ≈0)", fontsize=12)
axes[2].set_xlabel("x")
axes[2].set_ylabel("y")
plt.colorbar(c3, ax=axes[2])

plt.tight_layout()
plt.savefig("traction_bottom_surface.png", dpi=150)
print("Saved traction_bottom_surface.png")
plt.show()
# Out:
# Saved traction_bottom_surface.png
